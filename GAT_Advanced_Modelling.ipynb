# %% [markdown]
# # Particle Identification using GNN on HGCAL datase

# %% [markdown]
# We have already done the following:
# 1. Added a Gaussian Noise.
# 2. We had done the normalization per hit per layer. This had completely removed the longitudinal profile information. We only had the lateral profile- per layer relative energy at each hit cell, with respect to the hit cell with maximum energy deposit in that particular layer
# 3. We added the longitudinal profile information manually using the *layer profile*, which is the normalized tensor, representing the per event relative total energy in each layer, with respect to the layer with maximum total hit energy.
# 4. We had developed a more **intense** architecture.

# %% [markdown]
# Now, we shall develop the **GAT**(Graph Attention Network)

# %% [markdown]
# ## Importing the required packages

# %%
#General packages
import uproot
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt

#Torch packages
import torch
import torch.nn as nn
import torch.nn.functional as F

#Packages for GNN
from torch_geometric.data import Data, Dataset
from torch_geometric.loader import DataLoader
#from torch_geometric.nn import GCNConv, global_add_pool
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ## ROOT ---> Numpy arrays

# %%
#file=uproot.open("ntuple_pi+_100GeV_100keve.root:AllLayers")
#branches=["hit_x","hit_y","hit_z","hit_l","hit_E"]
#events=file.arrays(branches,library="ak")

# %%
#events  ### Awkawrd array in Dictionary like format
#type(events)
#events.hit_x # Returns the awkard arrays for the hit_x for all events

# %%
#events[0].hit_x # Returns the hit_x data for the first event, as numpy arrays

# %% [markdown]
# ## Preparing the Dataset

# %%
#Defining the root files and their path names
particle_files={
    "pi+":"ntuple_pi+_100GeV_100keve.root:AllLayers",
    "e+":"ntuple_e+_100_GeV_100Keve.root:AllLayers",
    "Y":"ntuple_gamma_100GeV_25keve_p1.root:AllLayers",
    "K-":"ntuple_kaon-_100GeV_20keve_p1.root:AllLayers",
    "K+":"ntuple_kaon+_100GeV_20keve_p1.root:AllLayers",
    "K_0":"ntuple_kaon0L_100GeV_10keve_test.root:AllLayers",
    "mu+":"ntuple_mu+_100GeV_100keve.root:AllLayers",
    "n":"ntuple_neutron_100GeV_10keve_test.root:AllLayers",
    "p":"ntuple_proton_100GeV_20keve_p1.root:AllLayers"
}
particle_ids={
    "pi+":0,
    "e+":1,
    "Y":2,
    "K-":3,
    "K+":4,
    "K_0":5,
    "mu+":6,
    "n":7,
    "p":8
}

# %%
#Defining the root files and their path names
particle_files={
    "pi+":"ntuple_pi+_100GeV_100keve.root:AllLayers",
    "e+":"ntuple_e+_100_GeV_100Keve.root:AllLayers",
    "Y":"ntuple_gamma_100GeV_25keve_p1.root:AllLayers",
    
}
particle_ids={
    "pi+":0,
    "e+":1,
    "Y":2
}

# %%
branches=["hit_x","hit_y","hit_z","hit_l","hit_E"]
all_events=[]
all_labels=[]

for pname,file_path in particle_files.items():
    file=uproot.open(file_path)
    events=file.arrays(branches,library="ak")[:1000] #Only 1000 events for now
    #Assigning particle ids
    pid=particle_ids[pname]
    #Store everything as a tuple
    all_events.extend([(events[i],pid) for i in range(len(events))])

# %%
#Shuffling
from sklearn.utils import shuffle
all_events=shuffle(all_events,random_state=28)

# %%
all_events[0][0]
# Out:
# <Record {hit_x: [0, ...], hit_y: [...], ...} type='{hit_x: var * float64, h...'>

# %%
all_events[0][1]
# Out:
# 2

# %%
#pid = {v: k for k, v in particle_ids.items()}
#class_names=[pid[i] for i in range(len(pid))]

# %%
#len(class_names)

# %%
#for i,name in enumerate(class_names):
#    print(name)

# %%
all_events[4][1]
# Out:
# 0

# %%
np.sum(all_events[0][0].hit_E)
# Out:
# 0.8654343613016184

# %%
np.sum(all_events[0][0].hit_E)
# Out:
# 0.8654343613016184

# %% [markdown]
# ## Adding Noise

# %%
def add_HGCAL_noise(event,noise_mean,N=0.05,threshold_sigma=None,random_state=None):
    signal=np.array(event.hit_E)
    #Computing the sigma
    #sigma=np.sqrt((a**2)*signal + b**2)
    sigma=N
    #Compute the Gaussian noise, with this sigma
    noise=np.random.normal(loc=0.0,scale=sigma,size=np.size(signal))
    E_noisy=signal+noise
    #Clipping zero and negative energies
    E_noisy[E_noisy<=0]=0.0
    #Optional zero suppression- based on threshold
    if threshold_sigma is not None:
        threshold=threshold_sigma*b
        E_noisy[E_noisy<threshold]=0.0
    #Newly record the data
    event_noisy=ak.Record(
    {
        "hit_x":event.hit_x,
        "hit_y":event.hit_y,
        "hit_z":event.hit_z,
        "hit_l":event.hit_l,
        "hit_E":E_noisy
    })
    
    return event_noisy

# %%
np.random.seed(42) #For explaining reproductivity
all_events_noisy=[]
noise_mean=0.0
#noise_std=0.03

for event,pid in all_events:
    event_noisy=add_HGCAL_noise(event,noise_mean=noise_mean)
    all_events_noisy.append((event_noisy,pid))

# %%
all_events_noisy[0][0]
# Out:
# <Record {hit_x: [0, ...], hit_y: [...], ...} type='{hit_x: 697 * float64, h...'>

# %% [markdown]
# ## Longitudinal profile- Layer Energy Profile

# %%
def layer_profile(event,global_max_layers=50):
    layers=ak.to_numpy(event.hit_l)
    layers=torch.tensor(layers)
    energies=ak.to_numpy(event.hit_E)
    energies=torch.tensor(energies)
    layer_sums=torch.bincount(input=layers-1,weights=energies,minlength=global_max_layers)
    #Maximum energy
    max_energy=layer_sums.max()
    if max_energy>0:
        layer_sums_norm=layer_sums/max_energy
    #return torch.tensor(layer_sums_norm,dtype=torch.float64)
    layer_sums_norm=torch.unsqueeze(layer_sums_norm,0)
    return layer_sums_norm

# %%
#Test
layer_profile(all_events_noisy[4][0]).shape
# Out:
# torch.Size([1, 50])

# %%
#layer_profile(all_events_noisy[5][0])

# %%
#A=torch.tensor([1,2,3])
#B=torch.unsqueeze(A,0)
#B.shape
#A.unsqueeze(0)
#print(A.shape)

# %% [markdown]
# ## Lateral Profile- Average energy per hits per layer

# %%
def normalize_hits_by_layer(event):
    layer=ak.to_numpy(event.hit_l)
    energy=ak.to_numpy(event.hit_E)
    #Prepare an array to store normalized energies
    energy_norm=np.zeros_like(energy)
    #Finding unique layers
    unique_layer=np.unique(layer)
    for l in unique_layer:
        #Extract the inndices of the hits in this layer
        mask=layer==l
        if np.any(mask):
            max_energy=energy[mask].max()
            if max_energy>0:
                energy_norm[mask]=energy[mask]/max_energy
            elif max_energy==0:
                energy_norm[mask]=0.0
    #Rebuild the record
    event_norm=ak.Record({
        "hit_x":event.hit_x,
        "hit_y":event.hit_y,
        "hit_z":event.hit_z,
        "hit_l":event.hit_l,
        "hit_E":energy_norm
    })
    return event_norm

# %%
all_events_normalized=[]
for event,pid in all_events_noisy:
    event_norm=normalize_hits_by_layer(event)
    all_events_normalized.append((event_norm,pid))

# %% [markdown]
# ## Creating the event graphs

# %%
def create_graph(event,k=8):
    x=ak.to_numpy(event.hit_x)
    y=ak.to_numpy(event.hit_y)
    z=ak.to_numpy(event.hit_z)
    l=ak.to_numpy(event.hit_l)
    E=ak.to_numpy(event.hit_E)
    #Removing zero energy hits
    mask_E=E>0
    x,y,z,l,E=x[mask_E],y[mask_E],z[mask_E],l[mask_E],E[mask_E]
    coords=np.column_stack((x,y,z))
    N=len(coords)
    if N<k+1:
        return None
    
    #Node features
    node_features=torch.from_numpy(np.column_stack((x,y,z,l,E))).float()

    #Global KNN
    knn=NearestNeighbors(n_neighbors=k+1,algorithm="kd_tree").fit(coords)
    knn_dist,knn_idx=knn.kneighbors(coords)
    knn_idx=knn_idx[:,1:] #Removes the self hit
    #print(knn_dist[9,:],knn_idx[9,:])

    #Edge construction
    src=np.repeat(np.arange(N),k)
    dst=knn_idx.reshape(-1)
    mask=dst>=0
    src,dst=src[mask],dst[mask]
    edge_index=torch.tensor(np.vstack([src,dst]),dtype=torch.long)

    #Edge attributes
    edge_attr = torch.tensor((E[src] * E[dst]).reshape(-1, 1),dtype=torch.float)

    #Final creation
    graph= Data(x=node_features,edge_index=edge_index,edge_attr=edge_attr)
    return graph

# %%
#graph=[create_graph(event,k=8) for event in events]

# %%
#creating graphs for all events
graph=[]
for event,pid in all_events_noisy:
    g=create_graph(event,k=8)
    profile=layer_profile(event,global_max_layers=50)
    if g is not None:
        g.y=torch.tensor([pid],dtype=torch.long)
        g.layer_profile=profile
        graph.append(g)

# %%
graph[0]
# Out:
# Data(x=[356, 5], edge_index=[2, 2848], edge_attr=[2848, 1], y=[1], layer_profile=[1, 50])

# %%
#Debugging-1
#for g in graph[:20]:
#    print(g.y.item())

# %%
#Debugging-2
#g = graph[3]
#print(g.y)
#print(g.y.shape)

# %%
#Test-1
graph[:20]
# Out:
# [Data(x=[356, 5], edge_index=[2, 2848], edge_attr=[2848, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[375, 5], edge_index=[2, 3000], edge_attr=[3000, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[368, 5], edge_index=[2, 2944], edge_attr=[2944, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[355, 5], edge_index=[2, 2840], edge_attr=[2840, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[371, 5], edge_index=[2, 2968], edge_attr=[2968, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[238, 5], edge_index=[2, 1904], edge_attr=[1904, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[338, 5], edge_index=[2, 2704], edge_attr=[2704, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[340, 5], edge_index=[2, 2720], edge_attr=[2720, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[335, 5], edge_index=[2, 2680], edge_attr=[2680, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[286, 5], edge_index=[2, 2288], edge_attr=[2288, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[147, 5], edge_index=[2, 1176], edge_attr=[1176, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[338, 5], edge_index=[2, 2704], edge_attr=[2704, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[394, 5], edge_index=[2, 3152], edge_attr=[3152, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[380, 5], edge_index=[2, 3040], edge_attr=[3040, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[347, 5], edge_index=[2, 2776], edge_attr=[2776, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[409, 5], edge_index=[2, 3272], edge_attr=[3272, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[390, 5], edge_index=[2, 3120], edge_attr=[3120, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[164, 5], edge_index=[2, 1312], edge_attr=[1312, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[375, 5], edge_index=[2, 3000], edge_attr=[3000, 1], y=[1], layer_profile=[1, 50]),
#  Data(x=[354, 5], edge_index=[2, 2832], edge_attr=[2832, 1], y=[1], layer_profile=[1, 50])]

# %%
#Test-2
graph[2].layer_profile
# Out:
# tensor([[0.0926, 0.0491, 0.1747, 0.3392, 0.1569, 0.6909, 0.5886, 0.6619, 0.4474,
#          0.5147, 1.0000, 0.6290, 0.6489, 0.6519, 0.4424, 0.6435, 0.4979, 0.4151,
#          0.5834, 0.3157, 0.1833, 0.3734, 0.1120, 0.1871, 0.0288, 0.0640, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0000, 0.0000, 0.0000, 0.0000, 0.0000]], dtype=torch.float64)

# %% [markdown]
# ## Splitting into training and testing

# %%
from sklearn.model_selection import train_test_split

#First split: Train vs Temp(Val+Test)
train_data, temp_data= train_test_split(graph, test_size=0.3, random_state=42)

#Second split: Test vs Val
val_data, test_data= train_test_split(temp_data, test_size=0.7, random_state=42)

print(f"Training samples: {len(train_data)}")
print(f"Validation samples: {len(val_data)}")
print(f"Test samples: {len(test_data)}")
# Out:
# Training samples: 2100
# Validation samples: 270
# Test samples: 630

# %%
#graph[:64]

# %% [markdown]
# ## Using DataLoader

# %%
from torch_geometric.loader import DataLoader
batch_size=64

train_loader=DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader=DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader=DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Making the GCN

# %% [markdown]
# ### Developing the Message Passing Block

# %%
#Making the message passing network
import torch
from torch.nn import Linear, Parameter
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree
class GCNConv(MessagePassing):
    def __init__(self,in_channels,out_channels):
        #Here, in_channels: Input node features
        super().__init__(aggr='add')
        self.lin=Linear(in_channels,out_channels,bias=False)
        self.bias = Parameter(torch.Tensor(out_channels))
        self.reset_parameters()
        
    def reset_parameters(self):
        self.lin.reset_parameters()
        self.bias.data.zero_()
        
    def forward(self,x,edge_index):
        # x has the shape [No. of hits, in_channels]
        #edge_index has shape [2, No. of edges]
        #Step-1: Add self loops
        edge_index,_=add_self_loops(edge_index,num_nodes=x.size(0))
        #Step-2: Linearly transform node feature matrix
        x=self.lin(x)
        #Step-3: Compute Normalization
        row,col=edge_index
        deg=degree(col,x.size(0))
        deg_inv_sqr=deg.pow(-0.5)
        deg_inv_sqr[deg_inv_sqr==float('inf')]=0
        norm=deg_inv_sqr[row]*deg_inv_sqr[col]
        #Step-4-5: Propagating the message- Normalize the node features and then add
        out=self.propagate(edge_index,x=x,norm=norm)
        #Step 6: Apply the end bias vector
        out=out+self.bias
        
        return out
    
    def message(self, x_j, norm):
        return norm.view(-1,1)*x_j

# %% [markdown]
# ### Stacking the GNN layers for 'Convolution'

# %% [markdown]
# #### Advanced Model

# %%
import torch
from torch import nn
import torch.nn.functional as F
#from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_add_pool,BatchNorm

class GCN_Event_Classifier(nn.Module):
    def __init__(self, input_dim,hidden_dim,output_dim):
        super().__init__()
        #The GCN Layers
        ## First-layer
        self.conv1=GCNConv(input_dim,hidden_dim)
        self.bn1=BatchNorm(hidden_dim)
        ## 6 repeated blocks
        self.convs=nn.ModuleList()
        self.bns=nn.ModuleList()
        for i in range(6):
            self.convs.append(GCNConv(hidden_dim,hidden_dim))
            self.bns.append(BatchNorm(hidden_dim))
        ##Final layer
        self.final_conv=GCNConv(hidden_dim,hidden_dim)
        #Regularization
        self.dropout=nn.Dropout(p=0.1)
        
        #Output- MLP- mainly doing the classification task.
        self.output=nn.Sequential(
            nn.Linear(hidden_dim+50,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,output_dim)
        )
        
    def forward(self,data):
        #x,edge_index=data.x, data.edge_index
        x,edge_index,batch=data.x,data.edge_index,data.batch
        #print(data.x.shape)
        
        #-----------Graph Convolution--------------
        #####First GCN Block#######
        x=self.conv1(x,edge_index)
        x=self.bn1(x)
        x=F.relu(x)
        x=self.dropout(x)
        #### Repeated convolutions ####
        for conv,bn in zip(self.convs,self.bns):
            x=conv(x,edge_index)
            x=bn(x)
            x=F.relu(x)
            x=self.dropout(x)
        #### Final convolution ####
        x=self.final_conv(x,edge_index)
        #Saving the node embeddings
        node_embedding=x
        #print(node_embedding.shape)
        
        #Graph-level event embedding
        event_embedding=global_add_pool(x,batch) # shape: [batch_size,hidden_dim]
        #print(event_embedding.shape)
        
        #Get layer profile
        layer_profile=data.layer_profile
        #print(layer_profile.shape)
        #if layer_profile.dim()==1:
        #    layer_profile=layer_profile.unsqueeze(0)
        layer_profile=layer_profile.float()
        #layer_profile.unsqueeze(0)
        #if layer_profile.size(0)!=event_embedding.size(0):
        #    layer_profile=layer_profile.expand(event_embedding.size(0),-1)
            
        
        #layer_profile=data.layer_profile.float()
        #Combined- Concatenate the features
        combined=torch.cat([event_embedding,layer_profile],dim=1)
        #print(combined.shape)
        #Node-level-predictions
        out=self.output(combined)
        
        return out,node_embedding

# %% [markdown]
# ## Making the GAT

# %% [markdown]
# ### Making the Message Passing Block

# %% [markdown]
# ### Stacking the GAT layers

# %%
import torch
from torch import nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv
from torch_geometric.nn import global_add_pool,BatchNorm

class GAT_Event_Classifier(nn.Module):
    def __init__(self, input_dim,hidden_dim,output_dim,heads):
        super().__init__()
        self.heads=heads
        #The GCN Layers
        ## First-layer
        #self.conv1=GCNConv(input_dim,hidden_dim)
        self.conv1=GATConv(input_dim,hidden_dim, heads=heads,concat=False,dropout=0.1) 
        #concat=False means 'mean of two heads
        self.bn1=BatchNorm(hidden_dim)
        ## 6 repeated blocks
        self.convs=nn.ModuleList()
        self.bns=nn.ModuleList()
        for i in range(6):
            self.convs.append(GATConv(hidden_dim,hidden_dim,heads=heads,concat=False,dropout=0.1))
            self.bns.append(BatchNorm(hidden_dim))
        ##Final layer
        self.final_conv=GATConv(hidden_dim,hidden_dim,heads=heads,concat=False,dropout=0.1)
        #Regularization
        self.dropout=nn.Dropout(p=0.1)
        
        #Output- MLP- mainly doing the classification task.
        self.output=nn.Sequential(
            nn.Linear(hidden_dim+50,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,hidden_dim),
            #nn.ReLU(),
            nn.BatchNorm1d(hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,output_dim)
        )
        
    def forward(self,data):
        #x,edge_index=data.x, data.edge_index
        x,edge_index,batch=data.x,data.edge_index,data.batch
        #print(data.x.shape)
        
        #-----------Graph Convolution--------------
        #####First GCN Block#######
        x=self.conv1(x,edge_index)
        x=self.bn1(x)
        x=F.relu(x)
        x=self.dropout(x)
        #### Repeated convolutions ####
        for conv,bn in zip(self.convs,self.bns):
            x=conv(x,edge_index)
            x=bn(x)
            x=F.relu(x)
            x=self.dropout(x)
        #### Final convolution ####
        x=self.final_conv(x,edge_index)
        #Saving the node embeddings
        node_embedding=x
        #print(node_embedding.shape)
        
        #Graph-level event embedding
        event_embedding=global_add_pool(x,batch) # shape: [batch_size,hidden_dim]
        #print(event_embedding.shape)
        
        #Get layer profile
        layer_profile=data.layer_profile
        #print(layer_profile.shape)
        #if layer_profile.dim()==1:
        #    layer_profile=layer_profile.unsqueeze(0)
        layer_profile=layer_profile.float()
        #layer_profile.unsqueeze(0)
        #if layer_profile.size(0)!=event_embedding.size(0):
        #    layer_profile=layer_profile.expand(event_embedding.size(0),-1)
            
        
        #layer_profile=data.layer_profile.float()
        #Combined- Concatenate the features
        combined=torch.cat([event_embedding,layer_profile],dim=1)
        #print(combined.shape)
        #Node-level-predictions
        out=self.output(combined)
        
        return out,node_embedding

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cpu')

# %%
#model=GCN_Event_Classifier(input_dim=5,hidden_dim=64,output_dim=9).to(device)
layer_dim=graph[0].layer_profile.shape[0]
model=GAT_Event_Classifier(input_dim=5,hidden_dim=25,heads=2,output_dim=3).to(device)

# %%
model
# Out:
# GAT_Event_Classifier(
#   (conv1): GATConv(5, 25, heads=2)
#   (bn1): BatchNorm(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convs): ModuleList(
#     (0-5): 6 x GATConv(25, 25, heads=2)
#   )
#   (bns): ModuleList(
#     (0-5): 6 x BatchNorm(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (final_conv): GATConv(25, 25, heads=2)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (output): Sequential(
#     (0): Linear(in_features=75, out_features=25, bias=True)
#     (1): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Linear(in_features=25, out_features=25, bias=True)
#     (4): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Linear(in_features=25, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ### Developing the training, validation and testing loops

# %%
optimizer=torch.optim.Adam(model.parameters(),lr=0.0001)
criterion=torch.nn.CrossEntropyLoss()

# %%
#Training loop
def train():
    model.train()
    total_loss=0.0
    for batch in train_loader:
        batch=batch.to(device)
        optimizer.zero_grad()
        #Computing batchwise layer profiles
        #profiles=layer_profile_batchwise(batch,global_max_layers=50)
        out,_=model(batch)
        loss=criterion(out,batch.y)
        #Backpropagation
        loss.backward() 
        optimizer.step()
        total_loss+=loss.item()
        
    return total_loss/len(train_loader)

# %%
#Validation loop
def validate():
    model.eval()
    total_loss=0.0
    with torch.no_grad():
        for batch in val_loader:
            batch=batch.to(device)
            out,_=model(batch)
            loss=criterion(out,batch.y)
            total_loss+=loss.item()
    return total_loss/len(val_loader)

# %%
#Running the model
epochs=100
#epochs=500
train_losses=[]
val_losses=[]
for epochs in range(1,epochs+1):
    train_loss=train()
    val_loss=validate()
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    print(f"Epoch {epochs}, Train Loss: {train_loss:.4f}, Val loss: {val_loss:.4f}")
# Out:
# Epoch 1, Train Loss: 1.0947, Val loss: 1.0239
# Epoch 2, Train Loss: 0.9831, Val loss: 0.9247
# Epoch 3, Train Loss: 0.9088, Val loss: 0.8324
# Epoch 4, Train Loss: 0.8632, Val loss: 0.8322
# Epoch 5, Train Loss: 0.8236, Val loss: 0.8225
# Epoch 6, Train Loss: 0.7875, Val loss: 0.7780
# Epoch 7, Train Loss: 0.7614, Val loss: 0.7843
# Epoch 8, Train Loss: 0.7397, Val loss: 0.7340
# Epoch 9, Train Loss: 0.7170, Val loss: 0.7104
# Epoch 10, Train Loss: 0.6926, Val loss: 0.7030
# Epoch 11, Train Loss: 0.6763, Val loss: 0.6537
# Epoch 12, Train Loss: 0.6578, Val loss: 0.6537
# Epoch 13, Train Loss: 0.6475, Val loss: 0.6662
# Epoch 14, Train Loss: 0.6362, Val loss: 0.6399
# Epoch 15, Train Loss: 0.6266, Val loss: 0.6104
# Epoch 16, Train Loss: 0.6121, Val loss: 0.6252
# Epoch 17, Train Loss: 0.6028, Val loss: 0.5829
# Epoch 18, Train Loss: 0.5977, Val loss: 0.5701
# Epoch 19, Train Loss: 0.5836, Val loss: 0.5634
# Epoch 20, Train Loss: 0.5766, Val loss: 0.5593
# Epoch 21, Train Loss: 0.5688, Val loss: 0.5881
# Epoch 22, Train Loss: 0.5622, Val loss: 0.5229
# Epoch 23, Train Loss: 0.5561, Val loss: 0.5290
# Epoch 24, Train Loss: 0.5451, Val loss: 0.5528
# Epoch 25, Train Loss: 0.5466, Val loss: 0.5090
# Epoch 26, Train Loss: 0.5451, Val loss: 0.5030
# Epoch 27, Train Loss: 0.5332, Val loss: 0.4994
# Epoch 28, Train Loss: 0.5375, Val loss: 0.5077
# Epoch 29, Train Loss: 0.5278, Val loss: 0.5069
# Epoch 30, Train Loss: 0.5278, Val loss: 0.4874
# Epoch 31, Train Loss: 0.5310, Val loss: 0.5144
# Epoch 32, Train Loss: 0.5240, Val loss: 0.4922
# Epoch 33, Train Loss: 0.5303, Val loss: 0.5023
# Epoch 34, Train Loss: 0.5087, Val loss: 0.5109
# Epoch 35, Train Loss: 0.5129, Val loss: 0.4832
# Epoch 36, Train Loss: 0.5191, Val loss: 0.4927
# Epoch 37, Train Loss: 0.5192, Val loss: 0.4756
# Epoch 38, Train Loss: 0.5118, Val loss: 0.5240
# Epoch 39, Train Loss: 0.5064, Val loss: 0.4726
# Epoch 40, Train Loss: 0.5030, Val loss: 0.4946
# Epoch 41, Train Loss: 0.5032, Val loss: 0.4686
# Epoch 42, Train Loss: 0.5048, Val loss: 0.4849
# Epoch 43, Train Loss: 0.5032, Val loss: 0.4904
# Epoch 44, Train Loss: 0.4862, Val loss: 0.4532
# Epoch 45, Train Loss: 0.4955, Val loss: 0.4528
# Epoch 46, Train Loss: 0.4987, Val loss: 0.4682
# Epoch 47, Train Loss: 0.4936, Val loss: 0.4722
# Epoch 48, Train Loss: 0.4847, Val loss: 0.4658
# Epoch 49, Train Loss: 0.4909, Val loss: 0.4528
# Epoch 50, Train Loss: 0.4838, Val loss: 0.4678
# Epoch 51, Train Loss: 0.4836, Val loss: 0.5051
# Epoch 52, Train Loss: 0.4857, Val loss: 0.4630
# Epoch 53, Train Loss: 0.4921, Val loss: 0.4419
# Epoch 54, Train Loss: 0.4923, Val loss: 0.5153
# Epoch 55, Train Loss: 0.4876, Val loss: 0.4508
# Epoch 56, Train Loss: 0.4777, Val loss: 0.4383
# Epoch 57, Train Loss: 0.4867, Val loss: 0.4595
# Epoch 58, Train Loss: 0.4836, Val loss: 0.4484
# Epoch 59, Train Loss: 0.4794, Val loss: 0.5053
# Epoch 60, Train Loss: 0.4901, Val loss: 0.4719
# Epoch 61, Train Loss: 0.4846, Val loss: 0.5106
# Epoch 62, Train Loss: 0.4853, Val loss: 0.4811
# Epoch 63, Train Loss: 0.4693, Val loss: 0.4611
# Epoch 64, Train Loss: 0.4841, Val loss: 0.4507
# Epoch 65, Train Loss: 0.4765, Val loss: 0.4932
# Epoch 66, Train Loss: 0.4728, Val loss: 0.4494
# Epoch 67, Train Loss: 0.4746, Val loss: 0.4501
# Epoch 68, Train Loss: 0.4797, Val loss: 0.4824
# Epoch 69, Train Loss: 0.4707, Val loss: 0.4682
# Epoch 70, Train Loss: 0.4652, Val loss: 0.4882
# Epoch 71, Train Loss: 0.4730, Val loss: 0.4729
# Epoch 72, Train Loss: 0.4800, Val loss: 0.4699
# Epoch 73, Train Loss: 0.4688, Val loss: 0.4598
# Epoch 74, Train Loss: 0.4732, Val loss: 0.4554
# Epoch 75, Train Loss: 0.4760, Val loss: 0.4679
# Epoch 76, Train Loss: 0.4631, Val loss: 0.4797
# Epoch 77, Train Loss: 0.4591, Val loss: 0.4794
# Epoch 78, Train Loss: 0.4689, Val loss: 0.4624
# Epoch 79, Train Loss: 0.4754, Val loss: 0.4900
# Epoch 80, Train Loss: 0.4625, Val loss: 0.4525
# Epoch 81, Train Loss: 0.4692, Val loss: 0.4448
# Epoch 82, Train Loss: 0.4735, Val loss: 0.4614
# Epoch 83, Train Loss: 0.4697, Val loss: 0.4411
# Epoch 84, Train Loss: 0.4628, Val loss: 0.4803
# Epoch 85, Train Loss: 0.4648, Val loss: 0.4355
# Epoch 86, Train Loss: 0.4664, Val loss: 0.4413
# Epoch 87, Train Loss: 0.4603, Val loss: 0.4537
# Epoch 88, Train Loss: 0.4637, Val loss: 0.4386
# Epoch 89, Train Loss: 0.4609, Val loss: 0.4330
# Epoch 90, Train Loss: 0.4676, Val loss: 0.4817
# Epoch 91, Train Loss: 0.4637, Val loss: 0.4569
# Epoch 92, Train Loss: 0.4635, Val loss: 0.4496
# Epoch 93, Train Loss: 0.4641, Val loss: 0.4517
# Epoch 94, Train Loss: 0.4493, Val loss: 0.4474
# Epoch 95, Train Loss: 0.4574, Val loss: 0.4296
# Epoch 96, Train Loss: 0.4552, Val loss: 0.4637
# Epoch 97, Train Loss: 0.4587, Val loss: 0.4399
# Epoch 98, Train Loss: 0.4555, Val loss: 0.4327
# Epoch 99, Train Loss: 0.4514, Val loss: 0.4573
# Epoch 100, Train Loss: 0.4545, Val loss: 0.4694

# %%
#Visualizing the model performance
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.plot(range(1,len(train_losses)+1),train_losses,label="Training loss",color="Blue")
plt.plot(range(1,len(val_losses)+1),val_losses,label="Validation loss",color="Red")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation loss vs Epochs")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Inferences(Performance) of the model

# %%
# Testing the model
model.eval()
predictions=[]
true_labels=[]
probablities=[]

with torch.no_grad():
    for batch in test_loader:
        batch=batch.to(device)
        out,_=model(batch)
        preds=torch.argmax(out,dim=1)  #Predictions
        probs=torch.softmax(out,dim=1) #Probablities
        
        predictions.append(preds.cpu())
        true_labels.append(batch.y.cpu())
        probablities.append(probs.cpu())
    
predictions=torch.cat(predictions)
true_labels=torch.cat(true_labels)
probablities=torch.cat(probablities)

# %% [markdown]
# #### Confusion matrix

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

cm=confusion_matrix(true_labels,predictions,normalize='true')

# %%
pid = {v: k for k, v in particle_ids.items()}
class_names=[pid[i] for i in range(len(pid))]

# %%
plt.figure(figsize=(8,6))

sns.heatmap(cm,
            annot=True,
            fmt='.2%',
            cmap='Blues',
            xticklabels=class_names,
            yticklabels=class_names)

plt.xlabel("Predicted Particle")
plt.ylabel("True Particle")
plt.title("Confusion Matrix - Particle Identification")

plt.xticks(rotation=45)
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ROC curve

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve,auc

#Here, we need to convert the labels to one-hot levels for ROC only
num_classes=3
y_true_bin=label_binarize(true_labels.numpy(),classes=range(num_classes))
y_score=probablities.numpy()

plt.figure(figsize=(8,6))

for i in range(num_classes):
    fpr, tpr,_=roc_curve(y_true_bin[:,i],y_score[:,i])
    roc_auc=auc(fpr,tpr)
    plt.plot(fpr,tpr,label=f'{class_names[i]}(AUC={roc_auc:.2f})')
plt.grid()
plt.plot([0,1], [0,1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Multi-Class ROC Curves-GCN")
plt.legend()
plt.show()

# %% [markdown]
# #### Signal and Background distribution per particle

# %%
pid = {v: k for k, v in particle_ids.items()}
class_names=[pid[i] for i in range(len(pid))]
for i, name in enumerate(class_names):
    #Signal
    signal_mask = (true_labels == i)
    signal_probs = probablities[signal_mask, i].cpu().numpy()
    #Background
    background_mask=(true_labels!=i)
    background_probs=probablities[background_mask,i].cpu().numpy()
    #Plotting
    plt.figure(figsize=(6,5))
    plt.hist(signal_probs,bins=50,histtype='step',color='blue', density=True,linewidth=2,alpha=0.7,label='Signal')
    plt.hist(background_probs,bins=50,histtype='step',color='red', density=True,linewidth=2,alpha=0.7,linestyle='--',label='Background')
    plt.xlabel(f"P({name})")
    plt.ylabel("Normalised Entries")
    plt.title(f"Signal and Background Distribution for {name}")
    plt.yscale('log')
    plt.grid(True)
    plt.legend(loc='best')
    plt.show()

# %%
#Subplot view
pid = {v: k for k, v in particle_ids.items()}
class_names=[pid[i] for i in range(len(pid))]
num_classes=len(class_names)
#Plotting
import matplotlib.pyplot as plt
plt.style.use('default')
plt.rcParams.update({
    "font.size": 14,
    "axes.labelsize": 16,
    "axes.titlesize": 16,
    "xtick.labelsize": 14,
    "ytick.labelsize": 14,
    "axes.linewidth": 1.5,
})
fig,axes=plt.subplots(1,num_classes,figsize=(5*num_classes,2*num_classes),sharey=True)

for i,(ax,name) in enumerate(zip(axes,class_names)):
    #Signal
    signal_mask=(true_labels==i)
    signal_probs=probablities[signal_mask,i].cpu().numpy()
    #Background
    background_mask=(true_labels!=i)
    background_probs=probablities[background_mask,i].cpu().numpy()
    #Plotting
    #bins=np.linspace(0,1,50)
    #plt.figure(figsize=(6,5))
    ax.hist(signal_probs,bins=50,histtype='step',color='blue', density=True,linewidth=2,alpha=0.7,label='Signal')
    ax.hist(background_probs,bins=50,histtype='step',color='red', density=True,linewidth=2,alpha=0.7,linestyle='--',label='Background')
    ax.set_xlabel(f"P({name})")
    ax.set_ylabel("Density")
    ax.set_yscale('log')
    #ax.set_xlim(0,1)
    #plt.title(f"Probablity distribution of True {name}")
    #plt.show()
